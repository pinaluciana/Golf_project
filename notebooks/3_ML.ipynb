# %% [markdown]
# # Machine Learning Models for Major Championship Performance Prediction
#
# **Goal:** build predictive models to forecast tournament performance using Random Forest, XGBoost and. Train on historical data (2020-2024) and test on 2025 tournaments to evaluate real-world predictive power.
#
# **Models:**
# 1. Random Forest Regressor - Predict total score
# 2. XGBoost Regressor - Predict total score
# 3. Compare with baseline (Pooled Linear Regression)
